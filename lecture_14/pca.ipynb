# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
from sklearn.decomposition.pca import PCA
# Out:
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
X, y = make_blobs(n_samples=100, centers=2, random_state=42)

# %%
plt.figure()
plt.xlim(-15, 15)
plt.ylim(-15, 15)
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
X.shape
# Out:
# (100, 2)

# %%
model = PCA(1)

# %%
model.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=1, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
out = model.transform(X).

# %%
# k = plt.hist(out, bins=50) # only if n_comp is 1

# %%
# out.shape
# Out:
# (100, 1)

# %%
# plt.figure()
# plt.xlim(-15, 15)
# plt.ylim(-15, 15)
# plt.scatter(out[:, 0], out[:, 1], c=y)

# %%
sec = np.dot(X, model.components_.T)

back = np.dot(sec, model.components_)

# %%
plt.figure()
plt.xlim(-15, 15)
plt.ylim(-15, 15)
plt.scatter(back[:, 0], back[:, 1], c=y)

# %%
another = PCA()
another.fit(back)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
another.explained_variance_
# Out:
# array([2.57229889e+01, 6.93506121e-31])

# %%
sec.mean(axis=0)
# Out:
# array([ 3.06209055, -4.70241981])

# %%
another = sec - sec.mean(axis=0)

# %%
another[:5]
# Out:
# array([[ 5.13269283,  0.26163733],
#        [-5.19958729, -1.40868437],
#        [ 5.382188  ,  0.0885335 ],
#        [-4.43497115, -1.84926604],
#        [-4.40000411, -1.01259757]])

# %%
out[:5]
# Out:
# array([[ 5.13269283,  0.26163733],
#        [-5.19958729, -1.40868437],
#        [ 5.382188  ,  0.0885335 ],
#        [-4.43497115, -1.84926604],
#        [-4.40000411, -1.01259757]])

# %%
data = pd.read_csv("../datasets/mnist_train_small.csv", header=None).to_numpy()

# %%
X, y = data[:, 1:], data[:, 0]

# %%
pca_model = PCA(2)

# %%
X_mod = pca_model.fit_transform(X)

# %%
X_mod.shape
# Out:
# (20000, 2)

# %%
plt.scatter(X_mod[:, 0], X_mod[:, 1], c=y)

# %%
select = y < 4

# %%
X_select = X_mod[select]
y_select = y[select]

# %%
plt.scatter(X_select[:, 0], X_select[:, 1], c=y_select)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(4)

# %%
model.fit(X_mod, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#            weights='uniform')

# %%
model.score(X_select, y_select)
# Out:
# 0.7668898356664637

# %%
X_select.shape
# Out:
# (8215, 50)

# %%
pca_model.explained_variance_.shape
# Out:
# (50,)

# %%
plt.plot(pca_model.explained_variance_ratio_)

# %%
pca_model.n_components_
# Out:
# 784

# %%
plt.imshow(X_show[0].reshape(28, 28))

# %%
X_show = pca_model.transform(X[:10])

# %%
pca_model.components_
# Out:
# array([[ 3.33665651e-17,  3.62786422e-18,  2.71284744e-19, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-1.00196336e-16, -1.82612309e-17,  1.97022012e-18, ...,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00]])

# %%
pca_three = PCA(100)

# %%
pca_three.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=100, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
X_three = np.dot(X, pca_three.components_.T)

# %%
X_three.shape
# Out:
# (20000, 100)

# %%
X_rev = np.dot(X_three, pca_three.components_)

# %%
X_rev.shape
# Out:
# (20000, 784)

# %%
plt.imshow(X_rev[4].reshape(28, 28))

# %% [markdown]
# ```
#
# pip install nltk
#
# ```

# %% [markdown]
# ```
#
# import nltk
#
# nltk.download("popular")
#
# ```
