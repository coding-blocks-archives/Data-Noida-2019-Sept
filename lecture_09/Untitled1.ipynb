# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("../datasets/mnist_train_small.npy")

# %%
data.shape
# Out:
# (19999, 785)

# %%
X, y = data[:, 1:], data[:, 0]

# %%
X.shape
# Out:
# (19999, 784)

# %%
X.dtype
# Out:
# dtype('uint8')

# %%
img = X[0].reshape(28, 28)

# %%
plt.imshow(img, cmap="gray")

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.33, random_state=42)

# %%
model = KNeighborsClassifier(20)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#            weights='uniform')

# %%
model.predict(X_test[:20])
# Out:
# array([1, 7, 0, 9, 4, 5, 4, 6, 9, 2, 0, 6, 1, 9, 9, 4, 9, 1, 6, 2],
#       dtype=uint8)

# %%
y_test[:20]
# Out:
# array([7, 7, 0, 9, 4, 5, 4, 6, 9, 2, 0, 6, 1, 9, 9, 4, 9, 1, 6, 2],
#       dtype=uint8)

# %%
model.score(X_test[:100], y_test[:100])
# Out:
# 0.95

# %%
np.product?
# Out:
# Signature: np.product(*args, **kwargs)
# Docstring:
# Return the product of array elements over a given axis.
#
# See Also
# --------
# prod : equivalent function; see for details.
# File:      /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py
# Type:      function

# %%
arr1 = np.zeros([10, 20])

# %%
arr2 = np.zeros([20, 20])

# %%
t = np.vstack([arr1, arr2])

# %%
t.shape
# Out:
# (30, 20)

# %%
y = np.full([10, 1], "Anuj")

# %%
X = np.zeros([10, 10000])

# %%
data = np.hstack([y, X])
