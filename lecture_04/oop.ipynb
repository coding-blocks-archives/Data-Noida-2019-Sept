# %%
class Human:
    pass

# %%
# def monkey_steel():
#     pass

# %%
mohit = Human()

# %%
print(mohit)
# Out:
# <__main__.Human object at 0x10a586908>

# %%
mohit.hands = 2

# %%
ravi = Human()

# %%
mohit.hands
# Out:
# 2

# %%
ravi.hands
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-de0d8075b6e2> in <module>
# ----> 1 ravi.hands
#
# AttributeError: 'Human' object has no attribute 'hands'

# %%
class Human:
    
    
    def __init__(self):
        self.hands = 2
        self.nose = 1

# %%
mohini = Human()

# %%
mohini.nose
# Out:
# 1

# %%
type(mohini)
# Out:
# __main__.Human

# %%
ram.hands
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-d0e54eee6e49> in <module>
# ----> 1 ram.hands
#
# NameError: name 'ram' is not defined

# %% [raw]
# type(ram)

# %%
class Human:

    def __init__(self, name="Unknown", hands=2):
        self.hands = 2
        self.nose = 1
        self.name = name

# %%
mohini = Human("Mohini Sharma")

# %%
mohini.name
# Out:
# 'Mohini Sharma'

# %%
kude_wala = Human(hands=4)

# %%
kude_wala.name
# Out:
# 'Unknown'

# %%
kude_wala.hands
# Out:
# 2

# %%
class Human(object):

    population = 0
    
    def __init__(self, name="Unknown", hands=2):
        self.hands = 2
        self.nose = 1
        self.name = name
        self.balance = 1000
        Human.population += 1
        
    def party(self):
        
        if self.balance >= 200:
            self.balance -= 200
            print("Now i have", self.balance)
        else:
            print("Beta ghar se paise le ke aa")

    def udhaar(self, dost, amount):
        if dost.balance >= amount:
            dost.balance -= amount
            self.balance += amount
        else:
            print("Mai to khud gareeb hu yaar")
          
    def __repr__(self):
        
        return "Name is {}, balance is {}".format(self.name, self.balance)
            
    def __add__(self, b):
        return self.name + b.name

# %%
ravi = Human("Ravi Pandey")
mohit = Human("Mohit")

# %%
ravi + mohit
# Out:
# 'Ravi PandeyMohit'

# %%
print(a)
# Out:
# 77

# %%
# Human.population

# %%
for i in range(10):
    ravi.party()
# Out:
# Now i have 800
# Now i have 600
# Now i have 400
# Now i have 200
# Now i have 0
# Beta ghar se paise le ke aa
# Beta ghar se paise le ke aa
# Beta ghar se paise le ke aa
# Beta ghar se paise le ke aa
# Beta ghar se paise le ke aa

# %%
ravi.party()
# Out:
# Beta ghar se paise le ke aa

# %%
mohit = Human()

# %%
mohit.party()
# Out:
# Now i have 800

# %%
ravi.udhaar(mohit, 400)

# %%
ravi.balance
# Out:
# 400

# %%
mohit.balance
# Out:
# 400

# %%
ravi.udhaar(mohit, 400)

# %%
class Car:
    
    doors = 4
    
    def kuchbhi(self):
        self.doors = 6

# %%
Car.doors
# Out:
# 4

# %%
mycar = Car()

# %%
mycar.doors
# Out:
# 4

# %%
mycar.kuchbhi()

# %%
mycar.doors
# Out:
# 6

# %%
Car.doors
# Out:
# 4

# %%
class Human:

    population = 0
    balance = 1000
    
    def __init__(self, name="Unknown", hands=2):
        self.hands = 2
        self.nose = 1
        self.name = name
        Human.population += 1
        
    def party(self):
        
        if Human.balance >= 200:
            Human.balance -= 200
            print("Now i have", Human.balance)
        else:
            print("Beta ghar se paise le ke aa")

    def udhaar(self, dost, amount):
        if Human.balance >= amount:
            Human.balance -= amount
            Human.balance += amount
        else:
            print("Mai to khud gareeb hu yaar")

# %%
amit = Human()
mohit = Human()

# %%
amit.party()
# Out:
# Now i have 800

# %%
mohit.balance
# Out:
# 800

# %%
print(amit)
# Out:
# <__main__.Human object at 0x10a7439b0>
