# %%
from flask import Flask, render_template, request
import prediction

# %%
app = Flask("My-app")

# %%
@app.route("/")
def hello():
    return render_template("form.template", result="")

@app.route("/submit",  methods = ["post"])
def submit():
    text = request.form["text"]
    return render_template("form.template", result=prediction.predict(text))

@app.route("/submit",  methods = ["get"])
def back_login():
    return render_template("form.template")

# %%
app.run(port=5000)
# Out:
#  * Serving Flask app "My-app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Nov/2019 12:20:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2019 12:20:20] "POST /submit HTTP/1.1" 200 -
