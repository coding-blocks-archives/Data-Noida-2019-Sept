# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.zeros([100, 100, 3], dtype=int)

# %%
plt.imshow(img)

# %%
img.dtype
# Out:
# dtype('float64')

# %%
# img[:, :, 0] = 100

# %%
# plt.imshow(img)

# %%
img[:10].shape
# Out:
# (10, 100, 3)

# %%
img[:10, :, :].shape
# Out:
# (10, 100, 3)

# %%
img[20:-20, 20:-20] = 255

# %%
plt.imshow(img)

# %%
import cv2

# %%
pan = cv2.imread("panda.png")

# %%
type(pan)
# Out:
# numpy.ndarray

# %%
pan.shape
# Out:
# (970, 1600, 3)

# %%
plt.imshow(pan)

# %%
mod = 255 - pan

# %%
plt.imshow(mod)
