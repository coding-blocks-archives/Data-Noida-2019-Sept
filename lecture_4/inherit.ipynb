# %%
class Car:
    
    def __init__(self):
        self.door = 4
        self.lock = 1
        
    def start(self):
        print("start generic car")
        
 
    def stop(self):
        print("stop generic car")
        
    def __hash__(self):
        return 42

# %%
class Mustang(Car):
    
    def start(self, speed):
        print("start all new Mustang with speed ", speed)
    
    def fly(self):
        print("Ye gaadi udti hai")
        
    def adder(self, v1, v2, t=int):
        if t is int:
            pass
        if t is float:
            pass

# %%
myCar = Car()

# %%
myCar.door
# Out:
# 4

# %%
myMust = Mustang()

# %%
myMust.start()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-3ea5763ad2ed> in <module>
# ----> 1 myMust.start()
#
# TypeError: start() missing 1 required positional argument: 'speed'

# %%
myMust.fly()
# Out:
# Ye gaadi udti hai

# %%
myMust.start()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-3ea5763ad2ed> in <module>
# ----> 1 myMust.start()
#
# TypeError: start() missing 1 required positional argument: 'speed'

# %%
a = Car()

# %%
hash(a)
# Out:
# 42
