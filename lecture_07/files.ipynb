# %%
first = open("happy.txt", "wt")

# %%
type(first)
# Out:
# _io.TextIOWrapper

# %%
first.write("Welcome to this first")
first.write("line 2")
first.write("line 3")
# Out:
# 6

# %%
first.flush()

# %%
# second = open("happy.txt", "wt")

# second.write("Welcome to this second")

# second.flush()

# %%
li = ["Welcome to this first", "line 2", "line 3"]

# %%
first.writelines?
# Out:
# Signature: first.writelines(lines, /)
# Docstring: <no docstring>
# Type:      builtin_function_or_method

# %%
for line in li:
    first.write(line + "\n")

# %%
first.flush()

# %%
first.close()

# %%
second = open("happy.txt", "at")

# %%
type(second)
# Out:
# _io.TextIOWrapper

# %%
second.write("Now this is something")
# Out:
# 21

# %%
second.flush()

# %%
second.readable()
# Out:
# False
